# %% [markdown]
# <a href="https://colab.research.google.com/github/RecSys-lab/movifex_dataset/blob/main/examples/dataset_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MoViFex Dataset - Statistics**
#
# 🎬 Dataset: [link](https://huggingface.co/datasets/alitourani/MoViFex_Dataset/tree/main)
#
# 🎬 Framework: [link](https://github.com/RecSys-lab/MoViFex)

# %% [markdown]
# ## **[Step 1] Clone Dataset Management Toolkit**
#
# Clone the framework into your `GDrive` and prepare it for experiments.

# %%
# Clone the repo
# !git clone https://github.com/RecSys-lab/MoViFex.git

# Install the required library
# %cd MoViFex
# !pip install -e .

# Add the repository to the Python path
import sys
sys.path.append('/content/MoViFex')

# Go back to the root
# %cd ..
# Out:
# Cloning into 'MoViFex'...
# remote: Enumerating objects: 792, done.
# remote: Counting objects: 100% (368/368), done.
# remote: Compressing objects: 100% (251/251), done.
# remote: Total 792 (delta 197), reused 266 (delta 111), pack-reused 424 (from 1)
# Receiving objects: 100% (792/792), 1.03 MiB | 4.20 MiB/s, done.
# Resolving deltas: 100% (414/414), done.
# /content/MoViFex
# Obtaining file:///content/MoViFex
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.2.2)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.0.2)
# Requirement already satisfied: opencv-python>=4.9 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (4.11.0.86)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (3.10.0)
# Collecting pytube>=15.0 (from MoViFex==1.0.0)
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: scipy>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (1.15.3)
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.32.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (6.0.2)
# Requirement already satisfied: openai>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (1.78.1)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (1.6.1)
# Requirement already satisfied: tensorflow>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from MoViFex==1.0.0) (2.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.9->MoViFex==1.0.0) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>=0.27.0->MoViFex==1.0.0) (4.13.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->MoViFex==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->MoViFex==1.0.0) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->MoViFex==1.0.0) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.1->MoViFex==1.0.0) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.1->MoViFex==1.0.0) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (5.29.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.17.0->MoViFex==1.0.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.45.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=0.27.0->MoViFex==1.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.27.0->MoViFex==1.0.0) (0.16.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.0->MoViFex==1.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.0->MoViFex==1.0.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai>=0.27.0->MoViFex==1.0.0) (0.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.17.0->MoViFex==1.0.0) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.17.0->MoViFex==1.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.17.0->MoViFex==1.0.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.17.0->MoViFex==1.0.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.17.0->MoViFex==1.0.0) (0.1.2)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pytube, MoViFex
#   Running setup.py develop for MoViFex
# Successfully installed MoViFex-1.0.0 pytube-15.0.0
# /content

# %% [markdown]
# ## 🚀 **[Step 2] Use the Dataset and its Framework**

# %% [markdown]
# ### I. *Load the Dataset Metadata File*

# %%
import os
import json
import movifex
import pandas as pd
from movifex.utils import loadJsonFromUrl

# Variables
datasetName = "MoViFex-visual"
datasetMetadataUrl = "https://huggingface.co/datasets/alitourani/MoViFex_Dataset/resolve/main/stats.json"

# Fetch the metadata of the movie features dataset
print(f"- Fetching the dataset metadata from '{datasetMetadataUrl}' ...")
jsonData = loadJsonFromUrl(datasetMetadataUrl)
movifexDF = pd.DataFrame(jsonData)

print(f'- {datasetName} dataset is loaded into a DataFrame:')
movifexDF.head(5)
# Out:
# - Fetching the dataset metadata from 'https://huggingface.co/datasets/alitourani/MoViFex_Dataset/resolve/main/stats.json' ...
# - MoViFex-visual dataset is loaded into a DataFrame:
#            id                       title  year                      genres
# 0  0000000006                        Heat  1995   [Action, Crime, Thriller]
# 1  0000000050         Usual Suspects, The  1995  [Crime, Mystery, Thriller]
# 2  0000000111                 Taxi Driver  1976    [Crime, Drama, Thriller]
# 3  0000000150                   Apollo 13  1995    [Adventure, Drama, IMAX]
# 4  0000000165  Die Hard: With a Vengeance  1995   [Action, Crime, Thriller]

# %% [markdown]
# ### II. *Download MovieLenz-25M*

# %%
from movifex.utils import loadDataFromCSV
from movifex.datasets.movielens.downloader import downloadMovielens25m

# Variables
movielenzVariant = "ml-25m"
datasetPath = "/content/ML25"
movielenzUrl = f"https://files.grouplens.org/datasets/movielens/{movielenzVariant}.zip"

# Download the MovieLenz Dataset
print(f"Downloading the '{movielenzVariant}' dataset from '{movielenzUrl}' ...")
isDownloadSuccessful = downloadMovielens25m(movielenzUrl, datasetPath)
if not isDownloadSuccessful:
  print('- Seems like there was a problem while downloading!')
datasetPath = os.path.join(datasetPath, "ml-25m")

# Load the Files
print(f"\nLoading '{movielenzVariant}' files from '{datasetPath}' ...")
mlMoviesDF = loadDataFromCSV(os.path.join(datasetPath, "movies.csv"))
mlRatingsDF = loadDataFromCSV(os.path.join(datasetPath, "ratings.csv"))
print(f"{len(mlMoviesDF)} movies and {len(mlRatingsDF)} ratings have been loaded!")
mlMoviesDF.head(5)
# Out:
# Downloading the 'ml-25m' dataset from 'https://files.grouplens.org/datasets/movielens/ml-25m.zip' ...
# - Downloading the dataset from 'https://files.grouplens.org/datasets/movielens/ml-25m.zip' ...
# - Download completed and the dataset is saved as a 'zip' file!
# - Now, extracting the dataset files inside /content/ML25 ...
# - Dataset extracted to '/content/ML25' successfully!
# - Removing the zip file /content/ML25/ml-25m.zip ...
# - Zip file removed successfully!
#
# Loading 'ml-25m' files from '/content/ML25/ml-25m' ...
# 62423 movies and 25000095 ratings have been loaded!
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## **📊 [Step 3] Check Some Stats**

# %%
# Some preparations
movifexDF = movifexDF.rename(columns={'id': 'itemId'})
mlRatingsDF = mlRatingsDF.rename(columns={'movieId': 'itemId'})
movifexDF['itemId'] = movifexDF['itemId'].astype(str).astype(int)

def printStatistics(data: pd.DataFrame):
  interactions = data.shape[0]
  uniqueUsers = data['userId'].nunique()
  uniqueItems = data['itemId'].nunique()
  print('------------------------')
  print(f" - Total interactions: {interactions}")
  print(f" - |U|: {uniqueUsers}")
  print(f" - |I|: {uniqueItems}")
  print(f" - |R|/|U|: {interactions / uniqueUsers:.2f}")
  print(f" - |R|/|I|: {interactions / uniqueItems:.2f}")
  print(f" - |R|/(|U|*|I|): {interactions / (uniqueUsers * uniqueItems):.10f}")
  print('------------------------')

# Merged
mergedDF1 = pd.merge(mlRatingsDF, movifexDF, on='itemId', how='inner')
printStatistics(mergedDF1)
# Out:
# ------------------------
#  - Total interactions: 3189185
#  - |U|: 158146
#  - |I|: 274
#  - |R|/|U|: 20.17
#  - |R|/|I|: 11639.36
#  - |R|/(|U|*|I|): 0.0735988347
# ------------------------
